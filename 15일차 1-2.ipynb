# %% [markdown]
# pandas

# %% [markdown]
# 기초 데이터 분석 및 전처리

# %%
import pandas as pd

# %%
data = pd.read_csv('tt.csv',engine='python',encoding='cp949')

# %%
data
# Out:
#       시도  시군구      시간대  발생건수  사망자수  부상자수  중상   경상  부상신고
# 0     서울  종로구  00시-02시    76     1   114  23   83     8
# 1     서울  종로구  02시-04시    40     0    60  11   45     4
# 2     서울  종로구  04시-06시    43     0    58  13   37     8
# 3     서울  종로구  06시-08시    64     2    93  20   65     8
# 4     서울  종로구  08시-10시    94     0   132  29   71    32
# 5     서울  종로구  10시-12시   108     0   136  30   92    14
# 6     서울  종로구  12시-14시   111     1   137  30   92    15
# 7     서울  종로구  14시-16시   118     0   168  28  115    25
# 8     서울  종로구  16시-18시   105     0   138  28   91    19
# 9     서울  종로구  18시-20시   131     0   162  36  107    19
# 10    서울  종로구  20시-22시   115     1   167  34  121    12
# 11    서울  종로구  22시-24시   129     1   181  38  120    23
# 12    서울   중구  00시-02시    64     0    98  29   58    11
# 13    서울   중구  02시-04시    57     0    73  16   50     7
# 14    서울   중구  04시-06시    51     3    58  24   28     6
# 15    서울   중구  06시-08시    60     0    95  19   68     8
# ...

# %%
data.groupby(['시도']).mean()
# Out:
#           발생건수      사망자수        부상자수         중상          경상       부상신고
# 시도
# 강원   35.535545  0.933649   56.502370  12.601896   41.080569   2.819905
# 경기  143.677419  1.822581  218.209677  45.239247  154.008065  18.962366
# 경남   54.469194  1.578199   77.981043  27.549763   46.905213   3.526066
# 경북   52.503759  1.537594   78.642857  22.116541   52.853383   3.672932
# 광주  124.316667  1.266667  199.616667  24.733333  169.083333   5.800000
# 대구  137.489583  1.250000  201.375000  43.468750  141.812500  16.093750
# 대전  125.900000  1.550000  190.533333  33.950000  148.500000   8.083333
# 부산   62.171875  0.640625   85.770833  23.687500   55.140625   6.942708
# 서울  129.316667  1.013333  179.170000  37.940000  125.750000  15.480000
# 세종   66.250000  1.666667   95.166667  24.000000   68.666667   2.500000
# 울산   66.533333  1.316667   96.283333  25.983333   63.366667   6.933333
# 인천   65.230769  0.965812   93.811966  21.136752   67.709402   4.965812
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.values
# Out:
# array([['서울', '종로구', '00시-02시', ..., 23, 83, 8],
#        ['서울', '종로구', '02시-04시', ..., 11, 45, 4],
#        ['서울', '종로구', '04시-06시', ..., 13, 37, 8],
#        ...,
#        ['세종', '세종', '18시-20시', ..., 34, 131, 3],
#        ['세종', '세종', '20시-22시', ..., 19, 114, 1],
#        ['세종', '세종', '22시-24시', ..., 23, 61, 2]], dtype=object)

# %%
data.shape
# Out:
# (2712, 9)
